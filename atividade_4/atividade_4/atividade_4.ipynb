# %%
import pandas as pd;
import openpyxl;
path = r"H:\python\3etapa\atividade_4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"
indicador_1 = pd.read_excel(path, header = 2)

# %%
indicador_1

# %%
tabela_prime = indicador_1.iloc[0:5570, 1:]

# %%
tabela_prime

# %%
tabela_prime.columns

# %%
tabela_prime["diferença"] = tabela_prime['População Município 2010\n(Sinopse)'] - tabela_prime[ 'População Censo 2022']

# %%
tabela_prime.to_csv(r"H:\python\3etapa\atividade_4\diferença20222010.csv", sep=";")

# %%
tabela_fodastica= (
    
    tabela_prime.groupby("UF")[['População Município 2010\n(Sinopse)',"População Censo 2022", "diferença" ]]
    .sum()
    .reset_index()
)

# %%
tabela_prime.to_csv(r"H:\python\3etapa\atividade_4\diferença20222010estado.csv", sep=";")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
eg = indicador_1[indicador_1["uf_regiao"].isin(regioes)].copy()
reg["homens"] = (reg["homem_branca"] + reg["homem_preta_parda"]) / 2
reg["mulheres"] = (reg["mulher_branca"] + reg["mulher_preta_parda"]) / 2



reg_long = reg.melt(
    id_vars="uf_regiao",
    value_vars=["homens", "mulheres"],
    var_name="sexo",
    value_name="horas",
)



# Gráfico de barras:




fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(data=reg_long, x="uf_regiao", y="horas", hue="sexo", ax=ax)
ax.set_title("Afazeres domésticos por região e sexo")
ax.set_xlabel("Região")
ax.set_ylabel("Horas / semana")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 eg = indicador_1[indicador_1["uf_regiao"].isin(regioes)].copy()
#       4 reg["homens"] = (reg["homem_branca"] + reg["homem_preta_parda"]) / 2
#       5 reg["mulheres"] = (reg["mulher_branca"] + reg["mulher_preta_parda"]) / 2
#
# NameError: name 'indicador_1' is not defined
